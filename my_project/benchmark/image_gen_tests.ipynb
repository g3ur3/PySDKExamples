# %%
import os
from pathlib import Path
import gen_test_image_util as imgutil
import importlib
importlib.reload(imgutil)
# Out:
# <module 'gen_test_image_util' from '/home/gotom/PySDKExamples/examples/my_project/gen_test_image_util.py'>

# %%
image_dir = Path('/home/gotom/data_dir/split_pic/')
max_count = 800

# %%
# #Remove files
# source = imgutil.IterPicsDeliver(image_dir, max_count)

# it = iter(source)
# #print(next(it))

for res in imgutil.pics_deliver_gen(image_dir, max_count):
    try:
        if os.path.exists(res):
            os.remove(res)
    except StopIteration:
        print("Stop Iteration")
        break

# %%
source_image = './maami_1.jpg'
size = (224, 224)

picsL = []
picsL = imgutil.create_test_image_chunk(source_image, size)

imgutil.save_image_chunk(image_dir, picsL)
# Out:
# size:224x224
# 726
# [PosixPath('/home/gotom/data_dir/split_pic/chunk_000.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_001.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_002.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_003.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_004.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_005.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_006.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_007.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_008.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_009.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_010.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_011.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_012.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_013.jpg'),
#  PosixPath('/home/gotom/data_dir/split_pic/chunk_014.jpg'),
# ...
